# %% [markdown]
# # JobBKK Web Scraper (Data Analyst)
#
# This notebook scrapes JobBKK result pages, extracts structured fields, and exports CSV with the same schema style used in your JobThai/JobsDB outputs.

# %%
import re
import time
from datetime import datetime
from pathlib import Path

import pandas as pd
import requests
from bs4 import BeautifulSoup

SEARCH_URL = "https://jobbkk.com/jobs/lists/1/หางาน,data%20analyst,ทุกจังหวัด,ทั้งหมด.html?keyword_type=3&sort=4"
OUTPUT_CSV = "jobbkk_data-analyst_like-jobthai_20260217.csv"
MAX_PAGES = 10
SLEEP_SECONDS = 1.0

headers = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/121.0.0.0 Safari/537.36"
    ),
    "Accept-Language": "th-TH,th;q=0.9,en-US;q=0.8,en;q=0.7",
}


def clean_text(text: str) -> str:
    return re.sub(r"\s+", " ", (text or "")).strip()


def normalize_for_match(text: str) -> str:
    return re.sub(r"[^a-z0-9]+", " ", (text or "").lower()).strip()


def keyword_match_groups_from_query(search_keyword: str) -> list[list[str]]:
    term_variants = {
        "data": ["data"],
        "scientist": ["scientist", "science", "scien", "scient"],
        "science": ["science", "scientist", "scien", "scient"],
        "engineer": ["engineer", "engineering", "eng"],
        "analyst": ["analyst", "analytics", "analysis"],
        "developer": ["developer", "development", "dev"],
    }

    tokens = [token for token in normalize_for_match(search_keyword).split() if token]
    return [term_variants.get(token, [token]) for token in tokens]


def title_matches_keyword(title: str, keyword_groups: list[list[str]]) -> bool:
    if not keyword_groups:
        return True
    title_norm = normalize_for_match(title)
    return all(any(variant in title_norm for variant in group) for group in keyword_groups)


def extract_salary(text: str) -> str:
    patterns = [
        r"\d[\d,\s]*\s*[-–]\s*\d[\d,\s]*\s*บาท",
        r"\d[\d,\s]*\s*บาท",
        r"ตามตกลง|ตามประสบการณ์|ไม่ระบุเงินเดือน",
    ]
    for pattern in patterns:
        match = re.search(pattern, text)
        if match:
            return clean_text(match.group(0))
    return ""


def update_page_in_search_url(url: str, page_num: int) -> str:
    updated = re.sub(r"/jobs/lists/\d+/", f"/jobs/lists/{page_num}/", url)
    return updated


def extract_keyword_from_url(url: str) -> str:
    path = url.split("?")[0]
    parts = path.split(",")
    if len(parts) >= 2:
        return parts[1].replace("%20", " ")
    return ""


def guess_province_name(location_text: str) -> str:
    location_text = clean_text(location_text)
    if not location_text:
        return ""

    province_names = [
        "กรุงเทพมหานคร", "กระบี่", "กาญจนบุรี", "กาฬสินธุ์", "กำแพงเพชร", "ขอนแก่น", "จันทบุรี",
        "ฉะเชิงเทรา", "ชลบุรี", "ชัยนาท", "ชัยภูมิ", "ชุมพร", "เชียงราย", "เชียงใหม่", "ตรัง",
        "ตราด", "ตาก", "นครนายก", "นครปฐม", "นครพนม", "นครราชสีมา", "นครศรีธรรมราช", "นครสวรรค์",
        "นนทบุรี", "นราธิวาส", "น่าน", "บึงกาฬ", "บุรีรัมย์", "ปทุมธานี", "ประจวบคีรีขันธ์", "ปราจีนบุรี",
        "ปัตตานี", "พระนครศรีอยุธยา", "พังงา", "พัทลุง", "พิจิตร", "พิษณุโลก", "เพชรบุรี", "เพชรบูรณ์",
        "แพร่", "พะเยา", "ภูเก็ต", "มหาสารคาม", "มุกดาหาร", "แม่ฮ่องสอน", "ยะลา", "ยโสธร", "ร้อยเอ็ด",
        "ระนอง", "ระยอง", "ราชบุรี", "ลพบุรี", "ลำปาง", "ลำพูน", "เลย", "ศรีสะเกษ", "สกลนคร", "สงขลา",
        "สตูล", "สมุทรปราการ", "สมุทรสงคราม", "สมุทรสาคร", "สระแก้ว", "สระบุรี", "สิงห์บุรี", "สุโขทัย",
        "สุพรรณบุรี", "สุราษฎร์ธานี", "สุรินทร์", "หนองคาย", "หนองบัวลำภู", "อ่างทอง", "อุดรธานี", "อุตรดิตถ์",
        "อุทัยธานี", "อุบลราชธานี", "อำนาจเจริญ",
    ]

    for province in province_names:
        if province in location_text:
            return province
    return ""


def parse_jobbkk_card(card, page_num: int, keyword: str) -> dict:
    title_el = card.select_one(".joblist-name-urgent a[href*='/jobs/detail']")
    company_el = card.select_one(".joblist-company-name a")
    location_el = card.select_one(".position-location span:last-child")
    salary_el = card.select_one(".position-salary span:last-child")
    updated_el = card.select_one(".joblist-updatetime-md-upper a")

    title = clean_text(title_el.get_text(" ", strip=True) if title_el else "")
    company = clean_text(company_el.get_text(" ", strip=True) if company_el else "")
    location = clean_text(location_el.get_text(" ", strip=True) if location_el else "")
    salary = clean_text(salary_el.get_text(" ", strip=True) if salary_el else "")
    posted_date = clean_text(updated_el.get("title") if updated_el and updated_el.get("title") else "")

    href = title_el.get("href", "") if title_el else ""
    job_url = href if href.startswith("http") else f"https://jobbkk.com{href}" if href else ""

    if not job_url:
        company_id = card.get("data-com-id", "")
        job_id = card.get("data-job-id", "")
        if company_id and job_id:
            job_url = f"https://jobbkk.com/jobs/detailurgent/{company_id}/{job_id}"

    raw_text = clean_text(card.get_text("\n", strip=True))
    if not salary:
        salary = extract_salary(raw_text)
    if not posted_date and updated_el:
        posted_date = clean_text(updated_el.get_text(" ", strip=True))

    province_name = guess_province_name(location)

    return {
        "keyword": keyword,
        "province_code": "",
        "province_name": province_name,
        "page": page_num,
        "job_title": title,
        "company": company,
        "location": location,
        "salary": salary,
        "posted_date": posted_date,
        "job_url": job_url,
        "raw_text": raw_text,
    }


def scrape_jobbkk(search_url: str, max_pages: int = 10, sleep_seconds: float = 1.0) -> pd.DataFrame:
    keyword = extract_keyword_from_url(search_url)
    keyword_groups = keyword_match_groups_from_query(keyword)

    all_rows = []
    seen_urls = set()

    print(f"[Search] Starting JobBKK crawl: max_pages={max_pages}")

    for page_num in range(1, max_pages + 1):
        page_url = update_page_in_search_url(search_url, page_num)
        print(f"[Search] Page {page_num}/{max_pages} -> request")

        response = requests.get(page_url, headers=headers, timeout=30)
        response.raise_for_status()

        soup = BeautifulSoup(response.text, "html.parser")
        cards = soup.select("div.joblist-pos.jobbkk-list-company")
        print(f"[Search] Page {page_num}/{max_pages} -> found cards: {len(cards)}")

        if not cards:
            print(f"[Search] Page {page_num}/{max_pages} -> no cards, stopping")
            break

        page_rows = []
        for card in cards:
            row = parse_jobbkk_card(card, page_num=page_num, keyword=keyword)

            if not row["job_title"] or not row["job_url"]:
                continue
            if not title_matches_keyword(row["job_title"], keyword_groups):
                continue
            if row["job_url"] in seen_urls:
                continue

            seen_urls.add(row["job_url"])
            page_rows.append(row)

        if not page_rows:
            print(f"[Search] Page {page_num}/{max_pages} -> no keyword matches, stopping")
            break

        all_rows.extend(page_rows)
        print(f"[Search] Page {page_num}/{max_pages} -> kept {len(page_rows)} | cumulative={len(all_rows)}")

        if sleep_seconds > 0:
            time.sleep(sleep_seconds)

    df = pd.DataFrame(all_rows)

    if not df.empty:
        df = df[
            [
                "keyword",
                "province_code",
                "province_name",
                "page",
                "job_title",
                "company",
                "location",
                "salary",
                "posted_date",
                "job_url",
                "raw_text",
            ]
        ].drop_duplicates(subset=["job_url"])

    return df


jobs_df = scrape_jobbkk(
    SEARCH_URL,
    max_pages=MAX_PAGES,
    sleep_seconds=SLEEP_SECONDS,
)
print(f"\nTotal unique jobs: {len(jobs_df)}")

keyword_slug = "-".join(extract_keyword_from_url(SEARCH_URL).lower().split())
output_file = f"jobbkk_{keyword_slug}_{datetime.now().strftime('%Y%m%d')}.csv"
output_path = Path(output_file)
jobs_df.to_csv(output_path, index=False, encoding="utf-8-sig")
print(f"Saved to: {output_path.resolve()}")

jobs_df.head(20)
# Out:
# [Search] Starting JobBKK crawl: max_pages=10
# [Search] Page 1/10 -> request
# [Search] Page 1/10 -> found cards: 15
# [Search] Page 1/10 -> kept 10 | cumulative=10
# [Search] Page 2/10 -> request
# [Search] Page 2/10 -> found cards: 15
# [Search] Page 2/10 -> kept 5 | cumulative=15
# [Search] Page 3/10 -> request
# [Search] Page 3/10 -> found cards: 15
# [Search] Page 3/10 -> kept 1 | cumulative=16
# [Search] Page 4/10 -> request
# [Search] Page 4/10 -> found cards: 15
# [Search] Page 4/10 -> kept 4 | cumulative=20
# [Search] Page 5/10 -> request
# [Search] Page 5/10 -> found cards: 15
# [Search] Page 5/10 -> kept 1 | cumulative=21
# [Search] Page 6/10 -> request
# [Search] Page 6/10 -> found cards: 15
# [Search] Page 6/10 -> kept 6 | cumulative=27
# [Search] Page 7/10 -> request
# [Search] Page 7/10 -> found cards: 15
# [Search] Page 7/10 -> kept 2 | cumulative=29
# [Search] Page 8/10 -> request
# [Search] Page 8/10 -> found cards: 15
# [Search] Page 8/10 -> kept 2 | cumulative=31
# [Search] Page 9/10 -> request
# [Search] Page 9/10 -> found cards: 15
# [Search] Page 9/10 -> kept 4 | cumulative=35
# [Search] Page 10/10 -> request
# [Search] Page 10/10 -> found cards: 15
# [Search] Page 10/10 -> kept 1 | cumulative=36
#
# Total unique jobs: 36
# Saved to: G:\Users\Moss\Documents\PYTHON_PROJECT\Job_Market_Analyzer_Web_Scraping\Moss\jobbkk_data-analyst_20260217.csv
#          keyword province_code  province_name  page  \
# 0   data analyst                กรุงเทพมหานคร     1
# 1   data analyst                กรุงเทพมหานคร     1
# 2   data analyst                กรุงเทพมหานคร     1
# 3   data analyst                กรุงเทพมหานคร     1
# 4   data analyst                กรุงเทพมหานคร     1
# 5   data analyst                    สมุทรสาคร     1
# 6   data analyst                กรุงเทพมหานคร     1
# 7   data analyst                กรุงเทพมหานคร     1
# 8   data analyst                กรุงเทพมหานคร     1
# 9   data analyst                กรุงเทพมหานคร     1
# 10  data analyst                กรุงเทพมหานคร     2
# 11  data analyst                กรุงเทพมหานคร     2
# 12  data analyst                กรุงเทพมหานคร     2
# 13  data analyst                กรุงเทพมหานคร     2
# 14  data analyst                กรุงเทพมหานคร     2
# 15  data analyst                กรุงเทพมหานคร     3
# 16  data analyst                       ชลบุรี     4
# 17  data analyst                      นนทบุรี     4
# 18  data analyst                กรุงเทพมหานคร     4
# 19  data analyst                       นครปฐม     4
#
#                                             job_title  \
# 0                                        Data Analyst
# 1                                        Data Analyst
# 2                                        Data Analyst
# 3                                        Data Analyst
# 4                                        Data Analyst
# 5                                        DATA Analyst
# 6     เจ้าหน้าที่วิเคราะห์ข้อมูล (MIS / Data Analyst)
# 7                   นักวิเคราะห์ข้อมูล (Data Analyst)
# 8                    นักวิเคราะห์ข้อมูล(Data Analyst)
# 9           เจ้าหน้าที่วิเคราะห์ข้อมูล (Data Analyst)
# 10                                       Data Analyst
# 11                                       Data Analyst
# 12                                       Data Analyst
# 13                                       Data Analyst
# 14                      Data engineer or Data Analyst
# 15                               Data Analyst Officer
# 16                              Data Analyst (ชลบุรี)
# 17                              Business Data Analyst
# 18                              Business Data Analyst
# 19  เจ้าหน้าที่เครือข่ายบริหารคุณภาพสินทรัพย์ (Dat...
#
#                                        company                     location  \
# 0             บริษัท เอฟซีซี เซอร์วิสเซส จำกัด     กรุงเทพมหานคร เขตจตุจักร
# 1              บริษัท ไวท์ไลน์แอคทิเวชัน จำกัด     กรุงเทพมหานคร เขตราชเทวี
# 2              บริษัท พูนธนามาร์เก็ตติ้ง จำกัด    กรุงเทพมหานคร เขตลาดพร้าว
# 3            บริษัท อาร์เอสยู เฮลท์ แคร์ จำกัด     กรุงเทพมหานคร เขตคลองเตย
# 4         บริษัท แมส ช้อยส์ คอร์ปอเรชั่น จำกัด    กรุงเทพมหานคร เขตตลิ่งชัน
# 5                EP Asia Group Company Limited     สมุทรสาคร เมืองสมุทรสาคร
# 6     บริษัท เมืองไทยประกันชีวิต จำกัด (มหาชน)     กรุงเทพมหานคร เขตจตุจักร
# 7                       บริษัท อวิเอเท็ค จำกัด       กรุงเทพมหานคร เขตบางนา
# 8             บริษัท มาราธอน (ประเทศไทย) จำกัด  กรุงเทพมหานคร เขตบางกอกน้อย
# 9       บจก.คอสซูติค อินโนเวชั่น แลบอราทอรี่ส์     กรุงเทพมหานคร เขตพระโขนง
# 10                     บริษัท ไอโคเน็กซ์ จำกัด     กรุงเทพมหานคร เขตคลองเตย
# 11               บริษัท เทคซอฟต์ โฮลดิ้ง จำกัด     กรุงเทพมหานคร เขตยานนาวา
# 12               บริษัท เทคซอฟต์ โฮลดิ้ง จำกัด     กรุงเทพมหานคร เขตยานนาวา
# 13  บริษัท ชับบ์สามัคคีประกันภัย จำกัด (มหาชน)     กรุงเทพมหานคร เขตหลักสี่
# 14               บริษัท เทคซอฟต์ โฮลดิ้ง จำกัด    กรุงเทพมหานคร เขตห้วยขวาง
# 15             Mana Nature Innovation Thailand     กรุงเทพมหานคร เขตพระโขนง
# 16                           ไวร์เมช อินดัสทรี           ชลบุรี เมืองชลบุรี
# 17                บริษัท ปราชญา สุขภาศรม จำกัด              นนทบุรี บางใหญ่
# 18                          กลุ่มบริษัท ซีดีจี     กรุงเทพมหานคร เขตยานนาวา
# 19         บริษัท ธนาคารกสิกรไทย จำกัด (มหาชน)           นครปฐม เมืองนครปฐม
#
#                  salary       posted_date  \
# 0   17,000 - 22,000 บาท  17/02/2026 11:27
# 1               ตามตกลง  17/02/2026 09:51
# 2   20,000 - 30,000 บาท  17/02/2026 08:33
# 3               ตามตกลง  17/02/2026 08:21
# 4               ตามตกลง  16/02/2026 17:51
# 5               ตามตกลง  16/02/2026 14:57
# 6               ตามตกลง  13/02/2026 14:33
# 7               ตามตกลง  17/02/2026 10:39
# 8               ตามตกลง  11/02/2026 10:03
# 9   18,000 - 25,000 บาท  16/02/2026 18:39
# 10              ตามตกลง  17/02/2026 05:33
# 11  35,000 - 65,000 บาท  17/02/2026 02:33
# 12  25,000 - 65,000 บาท  16/02/2026 09:45
# 13              ตามตกลง  15/02/2026 15:33
# 14  30,000 - 40,000 บาท  16/02/2026 20:33
# 15  25,000 - 28,000 บาท  13/02/2026 05:51
# 16  20,000 - 30,000 บาท  17/02/2026 08:33
# 17  18,000 - 25,000 บาท  14/02/2026 07:51
# 18              ตามตกลง  07/02/2026 21:03
# 19              ตามตกลง  17/02/2026 05:51
#
#                                               job_url  \
# 0   https://jobbkk.com/jobs/detailurgent/33965/356851
# 1   https://jobbkk.com/jobs/detailurgent/58677/131...
# 2   https://jobbkk.com/jobs/detailurgent/42373/128...
# 3   https://jobbkk.com/jobs/detailurgent/40139/135...
# 4   https://jobbkk.com/jobs/detailurgent/43586/126...
# 5   https://jobbkk.com/jobs/detailurgent/193275/10...
# 6   https://jobbkk.com/jobs/detailurgent/161183/13...
# 7   https://jobbkk.com/jobs/detailurgent/180147/13...
# 8   https://jobbkk.com/jobs/detailurgent/205132/12...
# 9   https://jobbkk.com/jobs/detailurgent/203081/13...
# 10       https://jobbkk.com/jobs/detail/55877/1349731
# 11      https://jobbkk.com/jobs/detail/185707/1262707
# 12      https://jobbkk.com/jobs/detail/185707/1302504
# 13       https://jobbkk.com/jobs/detail/11750/1344410
# 14      https://jobbkk.com/jobs/detail/185707/1341053
# 15  https://jobbkk.com/jobs/detailurgent/200311/13...
# 16  https://jobbkk.com/jobs/detailurgent/180624/13...
# 17  https://jobbkk.com/jobs/detailurgent/229746/13...
# 18  https://jobbkk.com/jobs/detailurgent/157216/13...
# 19  https://jobbkk.com/jobs/detailurgent/25145/135...
#
#                                              raw_text
# 0   Data Analyst บริษัท เอฟซีซี เซอร์วิสเซส จำกัด ...
# 1   Data Analyst บริษัท ไวท์ไลน์แอคทิเวชัน จำกัด ร...
# 2   Data Analyst บริษัท พูนธนามาร์เก็ตติ้ง จำกัด ร...
# 3   Data Analyst บริษัท อาร์เอสยู เฮลท์ แคร์ จำกัด...
# 4   Data Analyst บริษัท แมส ช้อยส์ คอร์ปอเรชั่น จำ...
# 5   DATA Analyst EP Asia Group Company Limited รับ...
# 6   เจ้าหน้าที่วิเคราะห์ข้อมูล (MIS / Data Analyst...
# 7   นักวิเคราะห์ข้อมูล (Data Analyst) บริษัท อวิเอ...
# 8   นักวิเคราะห์ข้อมูล(Data Analyst) บริษัท มาราธอ...
# 9   เจ้าหน้าที่วิเคราะห์ข้อมูล (Data Analyst) บจก....
# 10  Data Analyst บริษัท ไอโคเน็กซ์ จำกัด 8 ชั่วโมง...
# 11  Data Analyst บริษัท เทคซอฟต์ โฮลดิ้ง จำกัด 11 ...
# 12  Data Analyst บริษัท เทคซอฟต์ โฮลดิ้ง จำกัด 1 ว...
# 13  Data Analyst บริษัท ชับบ์สามัคคีประกันภัย จำกั...
# 14  Data engineer or Data Analyst บริษัท เทคซอฟต์ ...
# 15  Data Analyst Officer Mana Nature Innovation Th...
# 16  Data Analyst (ชลบุรี) ไวร์เมช อินดัสทรี รับสมั...
# 17  Business Data Analyst บริษัท ปราชญา สุขภาศรม จ...
# 18  Business Data Analyst กลุ่มบริษัท ซีดีจี รับสม...
# 19  เจ้าหน้าที่เครือข่ายบริหารคุณภาพสินทรัพย์ (Dat...
